# %%
import pandas as pd

# %%
df=pd.read_csv('./data/Food_Inspections2.csv')

# %%
df
# Out:
#         Inspection ID                        DBA Name  \
# 0             1199279   SOPHIE'S AT SAKS FIFTH AVENUE
# 1             1383354  COFFEE SLASTICARNA DRINA, INC.
# 2             1199275   SOPHIE'S AT SAKS FIFTH AVENUE
# 3             1372340                          SUBWAY
# 4             1236130                     VINIS PIZZA
# ...               ...                             ...
# 159468        2555815                           Field
# 159469        2555821                 WILD FORK FOODS
# 159470        2555808                         FERRO'S
# 159471        2555802                 MARIANO'S #8539
# 159472        2555818                           White
#
#                         AKA Name  License #  Facility Type           Risk  \
# 0                       SOPHIE'S  2279054.0     Restaurant  Risk 1 (High)
# 1       COFFEE SLASTICARNA DRINA  1620573.0     Restaurant  Risk 1 (High)
# 2                       SOPHIE'S  2262339.0     Restaurant  Risk 1 (High)
# 3                         SUBWAY    70217.0     Restaurant  Risk 1 (High)
# 4                    VINIS PIZZA  2133603.0     Restaurant  Risk 1 (High)
# ...                          ...        ...            ...            ...
# 159468              Eugene Field    23211.0         School  Risk 1 (High)
# 159469           WILD FORK FOODS        0.0  Grocery Store   Risk 3 (Low)
# 159470                   FERRO'S    12342.0     Restaurant  Risk 1 (High)
# 159471                 MARIANO'S  2470443.0  Grocery Store  Risk 1 (High)
# 159472                     White    26431.0         School  Risk 1 (High)
#
#                                     Address     City State      Zip  \
# 0                       700 N MICHIGAN AVE   CHICAGO    IL  60611.0
# 1                      2501 W LAWRENCE AVE   CHICAGO    IL  60625.0
# 2                       700 N MICHIGAN AVE   CHICAGO    IL  60611.0
# 3                        300 E RANDOLPH ST   CHICAGO    IL  60601.0
# 4                      4009 W LAWRENCE AVE   CHICAGO    IL  60630.0
# ...                                     ...      ...   ...      ...
# 159468                  7019 N Ashland AVE   CHICAGO    IL  60626.0
# 159469                  2340 W BELMONT AVE   CHICAGO    IL  60618.0
# 159470                       200 W 31ST ST   CHICAGO    IL  60616.0
# 159471  3857 S DR MARTIN LUTHER KING JR DR   CHICAGO    IL  60653.0
# 159472            1136 W 122nd St (12200S)   CHICAGO    IL  60643.0
#
#        Inspection Date          Inspection Type             Results  \
# 0           01/02/2014                  License                Pass
# 1           01/02/2014                  Canvass                Pass
# 2           01/02/2014                  License                Pass
# 3           01/02/2014                  Canvass  Pass w/ Conditions
# 4           01/02/2014                  Canvass                Pass
# ...                ...                      ...                 ...
# 159468      05/16/2022                  Canvass                Pass
# 159469      05/16/2022  Complaint Re-Inspection                Pass
# 159470      05/16/2022                  Canvass                Pass
# 159471      05/16/2022                Complaint                Pass
# 159472      05/16/2022                  Canvass                Fail
#
#                                                Violations   Latitude  \
# 0                                                     NaN  41.894980
# 1       34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...  41.968483
# 2                                                     NaN  41.894980
# 3       21. * CERTIFIED FOOD MANAGER ON SITE WHEN POTE...  41.884624
# 4       31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...  41.968128
# ...                                                   ...        ...
# 159468  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  42.009665
# 159469  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.939576
# 159470  10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLI...  41.838345
# 159471  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  41.823983
# 159472  38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - ...  41.672337
#
#         Longitude                                  Location
# 0      -87.624400   (-87.62439997045513, 41.89497951109999)
# 1      -87.691409    (-87.6914089058082, 41.96848268957195)
# 2      -87.624400   (-87.62439997045513, 41.89497951109999)
# 3      -87.620476   (-87.62047604442976, 41.88462378463585)
# 4      -87.728428   (-87.72842822449891, 41.96812752502552)
# ...           ...                                       ...
# 159468 -87.669949   (-87.66994861861532, 42.00966462466127)
# 159469 -87.687160  (-87.68716009585553, 41.939575964330665)
# 159470 -87.631741  (-87.63174087271551, 41.838345000206886)
# 159471 -87.616854   (-87.61685389078539, 41.82398325151479)
# 159472 -87.650553   (-87.65055320582842, 41.67233661078134)
#
# [159473 rows x 17 columns]

# %%
df.rename(columns = {'DBA Name':'Name'}, inplace = True)

# %%
df2 = df.drop(columns=['Risk','AKA Name', 'License #','Results','Violations', 'Location'])

# %%
df2['Facility Type'].unique()
# Out:
# array(['Restaurant', 'TAVERN', "Children's Services Facility",
#        'Daycare (2 - 6 Years)', nan, 'Grocery Store', 'School',
#        'cooking school', 'Catering', 'Liquor', 'Hospital',
#        'Daycare Above and Under 2 Years', 'Bakery',
#        'convenience/drug store', 'Banquet Dining', 'BREWERY',
#        'BAKERY/DELI', 'WINE STORE', 'Golden Diner', 'Shelter',
#        'MUSIC VENUE', 'LIVE POULTRY', 'Mobile Food Dispenser',
#        'Cafeteria', 'Mobile Frozen Desserts Vendor', 'GROCERY/RESTAURANT',
#        'Long Term Care', 'SMOKEHOUSE', '1005 NURSING HOME',
#        'Mobile Food Preparer', 'HERBALIFE/ZUMBA',
#        'OUTREACH CULINARY KITCHEN', 'RESTAURANT/GROCERY STORE',
#        'Shared Kitchen User (Short Term)', 'GAS STATION/STORE', 'ROOFTOP',
#        'LOUNGE/BANQUET HALL', 'Deli', 'BAR/GRILL', 'Daycare Combo 1586',
#        'THEATER', 'RESTAURANT.BANQUET HALLS', 'Wholesale', 'BANQUET HALL',
#        'BEFORE AND AFTER SCHOOL PROGRAM', 'Other', 'CONVENIENCE STORE',
#        'Shared Kitchen', 'SCHOOL', 'convenience store',
#        'SUPPORTIVE LIVING', 'Special Event', 'CATERING/CAFE',
#        'SUPPORTIVE LIVING FACILITY', 'MOBILE FROZEN DESSERT VENDOR',
#        'employee kitchen', 'CHURCH', 'Grocery & Restaurant', 'banquets',
#        'bar', 'PUSH CARTS', 'cafeteria', 'PUBLIC SHCOOL',
#        'Daycare (Under 2 Years)', 'DAY CARE', 'CHURCH KITCHEN',
#        'ROOF TOPS', 'ROOF TOP', 'Wrigley Roof Top', 'CHARTER SCHOOL',
#        'Shared Kitchen User (Long Term)', 'PRIVATE SCHOOL',
#        'WRIGLEY ROOFTOP', 'STORE', 'GROCERY AND BUTCHER',
#        'Grocery(Sushi prep)', 'STADIUM', 'COLLEGE', 'GROCERY/GAS STATION',
#        'GROCERY STORE/ RESTAURANT', 'BANQUET FACILITY', 'COFFEE/TEA',
#        'GAS STATION', 'NORTHERLY ISLAND', 'Private School', 'PALETERIA',
#        'BANQUET', 'Navy Pier Kiosk', 'CHURCH/SPECIAL EVENTS',
#        'GROCERY STORE/BAKERY', 'CAFE/STORE', 'Church', 'MOVIE THEATRE',
#        '1584-DAY CARE ABOVE 2 YEARS',
#        'RETAIL STORE OFFERS COOKING CLASSES', 'RESTAURANT/HOSPITAL',
#        'Assisted Living Senior Care', 'CAFETERIA', 'donut shop',
#        'Daycare Night', 'CHARITY AID KITCHEN', 'CHARTER',
#        'HEALTH CARE STORE', 'ICE CREAM SHOP', 'GROCERY/BAKERY',
#        'GROCERY& RESTAURANT', 'RESTAURANT/BAKERY', 'UNIVERSITY CAFETERIA',
#        'TRUCK', 'CITY OF CHICAGO COLLEGE', 'BANQUET ROOM',
#        'GAS STATION/RESTAURANT', 'SENIOR DAY CARE', 'ASSISTED LIVING',
#        'PASTRY school', 'REST/GROCERY', 'ROOFTOPS', 'CULINARY SCHOOL',
#        'CANDY/GELATO', 'CULINARY ARTS SCHOOL', 'Coffee shop',
#        'REST/ROOFTOP', 'Tavern', 'CONVENIENCE', 'RETAIL STORE',
#        'HERBALCAL', 'HOT DOG CART', 'tavern',
#        'GROCERY STORE/COOKING SCHOOL', 'Banquet rooms',
#        'A-Not-For-Profit Chef Training Program', 'REHAB CENTER',
#        'BEVERAGE/SILVERWARE WAREHOUSE', 'AFTER SCHOOL PROGRAM',
#        'CONVENIENT STORE', 'Banquet Hall', 'meat packing',
#        'FITNESS CENTER', 'Rest/GYM', 'RESTAURANT/BAR', 'COOKING SCHOOL',
#        'butcher shop', 'MOVIE THEATER', 'HEALTH CENTER/NUTRITION CLASSES',
#        'video store', 'ART GALLERY W/WINE AND BEER', 'GELATO SHOP',
#        'COFFEE SHOP', 'JUICE BAR', 'BAKERY/GROCERY', 'DAYCARE',
#        'Restaurant(protein shake bar)', 'fitness center',
#        'HERBAL LIFE SHOP', 'LIQUOR STORE', 'BAR', 'TEACHING SCHOOL',
#        'COFFEE CART', 'convenience', 'GOLF COURSE',
#        'LIQUOR/GROCERY STORE/BAR', 'BOWLING LANES/BANQUETS', 'VFW HALL',
#        'GROCERY/SERVICE GAS STATION', 'GROCERY STORE/GAS STATION',
#        'PACKAGED FOOD DISTRIBUTION', 'dollar store', 'PACKAGED LIQUOR',
#        'GAS STATION/ GROCERY STORE', 'GROCERY/LIQUOR STORE',
#        'NUTRITION/HERBALIFE', '15 monts to 5 years old', 'THEATRE',
#        'CHARTER SCHOOL CAFETERIA', 'coffee shop', '1023', 'DAY CARE 1023',
#        'COFFEE KIOSK', 'REGULATED BUSINESS', 'COMMISSARY', 'MFD TRUCK',
#        'CANDY STORE', "1023 CHILDERN'S SERVICES FACILITY",
#        'MOBILE DESSERTS VENDOR', 'Banquet', 'ICE CREAM', 'NURSING HOME',
#        'GAS STATION/MINI MART', 'Dollar store', 'GROCERY',
#        'Poultry Slaughter', 'CUSTOM POULTRY SLAUGHTER', 'PUSHCART',
#        'DAY CARE 2-14', 'grocery', 'MOBILE FOOD DESSERTS VENDOR',
#        'Assisted Living', 'Live Poultry',
#        "1023-CHILDREN'S SERVICES FACILITY",
#        'Mobile frozen dessert vendor', "1023 CHILDERN'S SERVICE FACILITY",
#        'RIVERWALK', 'UNUSED STORAGE', 'FROZEN DESSERT PUSHCARTS',
#        'WAREHOUSE', 'MOBILE FOOD TRUCK',
#        "1023 CHILDERN'S SERVICE S FACILITY", 'Long Term Care Facility',
#        'TEMPORARY KIOSK', 'fish market', "CHILDERN'S SERVICE FACILITY",
#        'BREWPUB', 'Adult Family Care Center', 'HEALTH CENTER',
#        'Long-Term Care', "1023 CHILDREN'S SERVICES FACILITY",
#        'DAYCARE 6 WKS-5YRS', 'COFFEE  SHOP', 'GROCERY/ RESTAURANT',
#        'CHILDRENS SERVICES FACILITY', 'CONVENIENCE/GAS STATION',
#        'DISTRIBUTION CENTER', 'CELL PHONE STORE', 'DOLLAR STORE',
#        'HERBAL MEDICINE', 'HERBAL REMEDY', 'URBAN FARM', 'MASSAGE BAR',
#        'JUICE AND SALAD BAR', 'GROCERY STORE / GAS STATION',
#        'SLAUGHTER HOUSE/ GROCERY', 'snack shop', 'DAYCARE COMBO',
#        'grocery/dollar store', 'RETAIL FOOD/GAS STATION',
#        'SERVICE BAR/THEATRE', "CHILDERN'S SERVICES  FACILITY",
#        'DRUG/FOOD STORE', 'weight loss program', 'CHINESE HERBS',
#        'TEA STORE', 'GROCERY/CAFE', 'HERBAL', 'DAYCARE 2 YRS TO 12 YRS',
#        'GAS STATION STORE', 'GAS STATION/STORE GROCERY', 'DISTRIBUTOR',
#        'NIGHT CLUB', 'SOCIAL CLUB', 'COFFEE ROASTER', 'SPA',
#        'Museum/Gallery', 'Mobile Prepared Food Vendor', 'HERBAL LIFE',
#        'GROCERY/DRUG STORE', 'CHURCH/SPECIAL EVENT',
#        'MOBILE FROZEN DESSERTS VENDOR', 'ART GALLERY', 'Banquet/kitchen',
#        'VENDING MACHINE', 'TAP room/tavern/liquor store', 'smoothie bar',
#        'HOT DOG STATION', 'HERBALIFE', 'PREPACAKAGED FOODS',
#        'COMMISSARY FOR SOFT SERVE ICE CREAM TRUCKS',
#        'CHURCH (SPECIAL EVENTS)', 'DOLLAR & GROCERY STORE', 'DINING HALL',
#        'GOLF COURSE CONNCESSION STAND', 'MOBILPREPARED FOOD VENDOR',
#        'RETAIL WINE/WINE BAR', 'RESTAURANT/BAR/THEATER', 'Airport Lounge',
#        'KITCHEN DEMO', 'GYM STORE', 'school cafeteria', 'HOSTEL',
#        'RESTAURANT AND LIQUOR', 'PRE PACKAGED', 'WEIGHT LOSS PROGRAM',
#        'CATERING/BANQUET', 'Herabalife', 'DELI/GROCERY STORE', 'Lounge',
#        'WHOLESALE & RETAIL', 'HERBAL DRINKS', 'LIQOUR BREWERY TASTING',
#        'SUMMER FEEDING PREP AREA', 'Gift Shop', 'Herbalife Nutrition',
#        'POPCORN CORN', 'Animal Shelter Cafe Permit', 'CANDY SHOP',
#        'HIGH SCHOOL KITCHEN', 'GAS STATION/FOOD', 'PREP INSIDE SCHOOL',
#        'EVENT SPACE', 'gas station', 'GROCERY/TAQUERIA',
#        'BANQUET HALL/CATERING', 'FURNITURE STORE', 'FRENCH MARKET SPACE',
#        'COLD/FROZEN FOOD STORAGE', 'HERBALIFE STORE',
#        'Shuffleboard Club with Bar', 'MOBILE FOOD', 'Laundromat',
#        'ADULT DAYCARE', 'RETAIL', 'BUTCHER SHOP', 'NOT-FOR-PROFIT CLUB',
#        'CLOTHING STORE', 'SHAKES/TEAS', 'Internet Cafe', 'KIOSK',
#        'youth housing', 'CULINARY CLASS ROOMS', 'DRUG STORE',
#        'FITNESS STUDIO', 'JUICE BAR/GROCERY', 'LIQUOR/COFFEE KIOSK',
#        'SUSHI COUNTER', 'PACKAGED HEALTH FOODS', 'TOBACCO STORE',
#        'Pop-Up Establishment Host-Tier II', 'GROCERY(GAS STATION)',
#        'EVENT VENU', 'VENDING COMMISSARY',
#        'Pop-Up Food Establishment User-Tier II', 'COMMISARY RESTAURANT',
#        '1475 LIQUOR', 'Food Pantry', 'DOLLAR TREE',
#        'GAS STATION/CONVENIENCE STORE', 'HELICOPTER TERMINAL',
#        'FOOD BOOTH', 'POULTRY SLAUGHTER', 'TAVERN/STORE', 'GROCERY/DELI',
#        'DELI/BAKERY', 'EXERCISE AND NUTRITION BAR', 'GAS STATION/GROCERY',
#        'CATERED LIQUOR', 'DOLLAR STORE WITH GROCERY', 'GYM',
#        'GROCERY STORE /PHARMACY', 'GROCERY STORE', 'HAIR SALON',
#        'MILK TEA', 'HOTEL', 'PRIVATE CLUB', 'PASTRY SCHOOL',
#        'hooka lounge', 'Tavern/Bar', 'PHARMACY', 'SERVICE GAS STATION',
#        'blockbuster video', 'CONVNIENCE STORE', 'liquor store',
#        'GAS STATION FOOD STORE',
#        'PREPACKAGE MEAL DISTRIBUTOR (1006 Retail)', 'NUTRITION SHAKES',
#        'REPACKAGING PLANT', 'PRIVATE EVENT SPACE', 'GENERAL STORE',
#        'MOBILE PUSH CART', 'EVENT CENTER', 'ART CENTER', 'KITCHEN',
#        'HEALTH FOOD STORE', 'health club', 'GREENHOUSE',
#        'DRUG STORE/GROCERY', 'hair salon', 'TEST KITCHEN/ STORAGE',
#        'Hair Salon', 'GROCERY & LIQUOR STORE', 'private school',
#        'Day Care Facility', 'MOBIL FOOD PREPARED', 'ARCHDIOCESE',
#        'FLEA MARKET', 'Pop-Up Establishment Host-Tier III',
#        'DISTILLERY WITH TASTING ROOM', 'LIVE POULTRY SLAUGHTER FACILITY',
#        'COLD STORAGE FACILITY'], dtype=object)

# %%
df2['Inspection Date'] = pd.to_datetime(df['Inspection Date'])

# %%
df2['year'] = df2['Inspection Date'].dt.year

# %%
df2=df2[(df2['year'] > 2013) & (df2['year'] < 2021)]

# %%
df2 = df2.drop(columns=['Inspection ID','Inspection Type'])

# %%
df2['Name'].str.title()
# Out:
# 0          Sophie'S At Saks Fifth Avenue
# 1         Coffee Slasticarna Drina, Inc.
# 2          Sophie'S At Saks Fifth Avenue
# 3                                 Subway
# 4                            Vinis Pizza
#                        ...
# 138218                 Gold Coast Market
# 138219                       Dragonbites
# 138220               Guidepost Fic B Llc
# 138221                Dollar Tree #06219
# 138222      La Malinche Coffee House Llc
# Name: Name, Length: 138223, dtype: object

# %%
df2['Name']=df2['Name'].str.title()
df2['Address']=df2['Address'].str.title()
df2['City']=df2['City'].str.title()

# %%
df2 = df2.drop(columns=['State','Zip','Inspection Date'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138223 entries, 0 to 138222
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Name           138223 non-null  object
#  1   Facility Type  136910 non-null  object
#  2   Address        138223 non-null  object
#  3   City           138137 non-null  object
#  4   Latitude       137766 non-null  float64
#  5   Longitude      137766 non-null  float64
#  6   year           138223 non-null  int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 8.4+ MB

# %%
df2.drop_duplicates()
# Out:
#                                   Name                 Facility Type  \
# 0        Sophie'S At Saks Fifth Avenue                    Restaurant
# 1       Coffee Slasticarna Drina, Inc.                    Restaurant
# 3                               Subway                    Restaurant
# 4                          Vinis Pizza                    Restaurant
# 5                Costello'S Sandwiches                    Restaurant
# ...                                ...                           ...
# 138213               Gold Coast Market                 Grocery Store
# 138214                        Sterch'S                        TAVERN
# 138215                     El Tequilas                    Restaurant
# 138217                         Foxtrot                    Restaurant
# 138220             Guidepost Fic B Llc  Children's Services Facility
#
#                      Address     City   Latitude  Longitude  year
# 0        700 N Michigan Ave   Chicago  41.894980 -87.624400  2014
# 1       2501 W Lawrence Ave   Chicago  41.968483 -87.691409  2014
# 3         300 E Randolph St   Chicago  41.884624 -87.620476  2014
# 4       4009 W Lawrence Ave   Chicago  41.968128 -87.728428  2014
# 5          2015 W Roscoe St   Chicago  41.943100 -87.679095  2014
# ...                      ...      ...        ...        ...   ...
# 138213  71-73 W Chicago Ave   Chicago  41.896529 -87.630992  2020
# 138214   2238 N Lincoln Ave   Chicago  41.922699 -87.645133  2020
# 138215   2826 N Lincoln Ave   Chicago  41.933101 -87.659683  2020
# 138217     2136 S Peoria St   Chicago  41.852794 -87.648284  2020
# 138220     1530 N Damen Ave   Chicago  41.909188 -87.677577  2020
#
# [83344 rows x 7 columns]

# %%
df2.to_csv('clean_Chicago_restaurants.csv', index=False)
