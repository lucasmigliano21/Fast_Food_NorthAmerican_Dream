# %%
import pandas as pd

# %%
df=pd.read_csv('./data/McDonalds.csv')

# %%
df
# Out:
#            geometry.coordinates  properties.addressLine1  \
# 0       [-86.787588, 36.156145]            1201 BROADWAY
# 1       [-86.812043, 36.145916]        2700 WEST END AVE
# 2       [-86.774905, 36.120827]    2612 8TH AVENUE SOUTH
# 3       [-86.743719, 36.142965]      524 MURFREESBORO RD
# 4         [-86.799331, 36.1906]       801 VANTAGE WAY CT
# ...                         ...                      ...
# 13796  [-124.054297, 46.342259]           100 16TH ST SE
# 13797  [-124.162087, 47.007879]  701 POINT BROWNE AVE NW
# 13798   [-131.672389, 55.34867]         2417 TONGASS AVE
# 13799  [-134.576119, 58.364486]            2285 TROUT ST
# 13800  [-135.349288, 57.060111]     913 HALIBUT POINT RD
#
#          properties.addressLine2 properties.addressLine3  \
# 0         NASHVILLE FIELD OFFICE               NASHVILLE
# 1         NASHVILLE FIELD OFFICE               NASHVILLE
# 2         NASHVILLE FIELD OFFICE               NASHVILLE
# ...

# %%
df['properties.subDivision'].value_counts()
# Out:
# CA    1288
# TX    1191
# FL     907
# IL     663
# NY     617
# OH     615
# MI     545
# PA     494
# NC     489
# GA     454
# VA     401
# IN     349
# TN     331
# MO     315
# WI     299
# AZ     289
# MD     288
# NJ     264
# WA     263
# KY     251
# AL     245
# LA     240
# MA     234
# SC     230
# MN     226
# CO     211
# OK     204
# AR     173
# OR     164
# KS     148
# IA     147
# MS     144
# NV     144
# CT     142
# UT     116
# NM     104
# WV     104
# NE      78
# ME      62
# ID      62
# NH      54
# MT      48
# DE      37
# RI      31
# SD      30
# WY      29
# DC      27
# VT      26
# ND      25
# AK       3
# Name: properties.subDivision, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x_values = df['properties.subDivision'].value_counts()
y_values = df['properties.subDivision'].value_counts().tolist()
plt.figure(figsize=(30,10))
plt.bar(x_values, y_values)
plt.show()
plt.close('all')

# %%
y_values = df['properties.subDivision'].value_counts().tolist()

# %%
x_values
# Out:
# array(['TN', 'KY', 'AL', 'GA', 'MS', 'IN', 'IL', 'MO', 'NC', 'AR', 'VA',
#        'SC', 'OH', 'WV', 'LA', 'FL', 'IA', 'MI', 'OK', 'PA', 'WI', 'KS',
#        'TX', 'MD', 'DC', 'NY', 'NE', 'MN', 'DE', 'NJ', 'SD', 'CT', 'MA',
#        'VT', 'ND', 'CO', 'RI', 'NH', 'NM', 'ME', 'WY', 'MT', 'AZ', 'UT',
#        'ID', 'NV', 'CA', 'OR', 'WA', 'AK'], dtype=object)
